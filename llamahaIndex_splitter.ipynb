# %% [markdown]
# # Code Hierarchy Node Parser

# %%
#%pip install llama-index-packs-code-hierarchy llama-index

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core.text_splitter import CodeSplitter
from llama_index.llms.openai import OpenAI
from llama_index.packs.code_hierarchy import CodeHierarchyNodeParser
from llama_index.packs.code_hierarchy import CodeHierarchyAgentPack
from pathlib import Path

# %%
documents = SimpleDirectoryReader(
    input_files=[Path("C:\Dev\POC\.venv\Lib\site-packages\pypdf\pagerange.py")],
    file_metadata=lambda x: {"filepath": x},
).load_data()


split_nodes = CodeHierarchyNodeParser(
    language="python",
    # You can further parameterize the CodeSplitter to split the code
    # into "chunks" that match your context window size using
    # chunck_lines and max_chars parameters, here we just use the defaults
    code_splitter=CodeSplitter(language="python", max_chars=1000, chunk_lines=10),
).get_nodes_from_documents(documents)

# %%
documents
# Out:
# [Document(id_='dd793fd2-0f9f-4291-bd14-a66d3abef34d', embedding=None, metadata={'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='"""\nRepresentation and utils for ranges of PDF file pages.\n\nCopyright (c) 2014, Steve Witham <switham_github@mac-guyver.com>.\nAll rights reserved. This software is available under a BSD license;\nsee https://github.com/py-pdf/pypdf/blob/main/LICENSE\n"""\n\nimport re\nfrom typing import Any, List, Tuple, Union\n\nfrom .errors import ParseError\n\n_INT_RE = r"(0|-?[1-9]\\d*)"  # A decimal int, don\'t allow "-0".\nPAGE_RANGE_RE = f"^({_INT_RE}|({_INT_RE}?(:{_INT_RE}?(:{_INT_RE}?)?)))$"\n# groups:         12     34     5 6     7 8\n\n\nclass PageRange:\n    """\n    A slice-like representation of a range of page indices.\n\n    For example, page numbers, only starting at zero.\n\n    The syntax is like what you would put between brackets [ ].\n    The slice is one of the few Python types that can\'t be subclassed,\n    but this class converts to and from slices, and allows similar use.\n\n      -  PageRange(str) parses a string representing a page range.\n      -  PageRange(slice) directly "imports" a slice.\n      -  to_slice() gives the equivalent slice.\n      -  str() and repr() allow printing.\n      -  indices(n) is like slice.indices(n).\n    """\n\n    def __init__(self, arg: Union[slice, "PageRange", str]) -> None:\n        """\n        Initialize with either a slice -- giving the equivalent page range,\n        or a PageRange object -- making a copy,\n        or a string like\n            "int", "[int]:[int]" or "[int]:[int]:[int]",\n            where the brackets indicate optional ints.\n        Remember, page indices start with zero.\n        Page range expression examples:\n\n            :     all pages.                   -1    last page.\n            22    just the 23rd page.          :-1   all but the last page.\n            0:3   the first three pages.       -2    second-to-last page.\n            :3    the first three pages.       -2:   last two pages.\n            5:    from the sixth page onward.  -3:-1 third & second to last.\n        The third, "stride" or "step" number is also recognized.\n            ::2       0 2 4 ... to the end.    3:0:-1    3 2 1 but not 0.\n            1:10:2    1 3 5 7 9                2::-1     2 1 0.\n            ::-1      all pages in reverse order.\n        Note the difference between this notation and arguments to slice():\n            slice(3) means the first three pages;\n            PageRange("3") means the range of only the fourth page.\n            However PageRange(slice(3)) means the first three pages.\n        """\n        if isinstance(arg, slice):\n            self._slice = arg\n            return\n\n        if isinstance(arg, PageRange):\n            self._slice = arg.to_slice()\n            return\n\n        m = isinstance(arg, str) and re.match(PAGE_RANGE_RE, arg)\n        if not m:\n            raise ParseError(arg)\n        elif m.group(2):\n            # Special case: just an int means a range of one page.\n            start = int(m.group(2))\n            stop = start + 1 if start != -1 else None\n            self._slice = slice(start, stop)\n        else:\n            self._slice = slice(*[int(g) if g else None for g in m.group(4, 6, 8)])\n\n    @staticmethod\n    def valid(input: Any) -> bool:\n        """\n        True if input is a valid initializer for a PageRange.\n\n        Args:\n            input: A possible PageRange string or a PageRange object.\n\n        Returns:\n            True, if the ``input`` is a valid PageRange.\n        """\n        return isinstance(input, (slice, PageRange)) or (\n            isinstance( ...

# %%
split_nodes
# Out:
# [TextNode(id_='152c4556-8642-48bd-bc08-32a95ce64d97', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [], 'start_byte': 0, 'end_byte': 6880, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='152c4556-8642-48bd-bc08-32a95ce64d97', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [], 'start_byte': 0, 'end_byte': 6880, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='0663bcdbc3b00129f4ade7223b2ebc7d664eb82c34baa8b69221bda7e727cebd'), <NodeRelationship.CHILD: '5'>: [RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484}, hash='4e7a3d7cf007226c1c8844b479ad34a7dfe3134dc15439846b967ef713665dd4'), RelatedNodeInfo(node_id='446ebec5-d6fa-4cd6-996d-58da053ef58c', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789}, hash='dfa01cf866eabb489a101430ff53300b1ef5991b15ab6cb74a44adcb90ae3e59')], <NodeRelationship.PARENT: '4'>: None}, text='"""\nRepresentation and utils for ranges of PDF file pages.\n\nCopyright (c) 2014, Steve Witham <switham_github@mac-guyver.com>.\nAll rights reserved. This software is available under a BSD license;\nsee https://github.com/py-pdf/pypdf/blob/main/LICENSE\n"""\n\nimport re\nfrom typing import Any, List, Tuple, Union\n\nfrom .errors import ParseError\n\n_INT_RE = r"(0|-?[1-9]\\d*)"  # A decimal int, don\'t allow "-0".\nPAGE_RANGE_RE = f"^({_INT_RE}|({_INT_RE}?(:{_INT_RE}?(:{_INT_RE}?)?)))$"\n# groups:         12     34     5 6     7 8\n\n\nclass PageRange:\n    # Code replaced for brevity. See node_id a4d522d2-982f-4cc6-ba4b-8870ac8ed52c\n\n\nPAGE_RANGE_ALL = PageRange(":")  # The range of all pages.\n\n\ndef parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:\n    # Code replaced for brevity. See node_id 446ebec5-d6fa-4cd6-996d-58da053ef58c\n\n\nPageRangeSpec = Union[str, PageRange, Tuple[int, int], Tuple[int, int, int], List[int]]', start_char_idx=0, end_char_idx=966, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='225ffd10d79e3e6c733ce02ba68d34f42775502a260be1ec364b2fc5a4450a03'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='7603a12a-ed6a-4623-a936-26f52007ed71', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='25885a51988162f1aca5a67c51403a1c41d71bde76b2fdab26d68f2ed8ff7a7f'), <NodeRelationship.CHILD: '5'>: [RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084}, hash='2ef2bf2eba9b983e0af7d61be24ec96613f9e939f24570afb2e2f740fa85358b'), RelatedNodeInfo(node_id='0f8e7127-6943-4098-a7f3-c5a9a5410751', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'valid', 'type': 'function_definition', 'signature': 'def valid(input: Any) -> bool:'}], 'start_byte': 3104, 'end_byte': 3528}, hash='d7444197514e880201f1c889cb8f4764ac072fbe6ee5cec252db7f6ddf949502'), RelatedNodeInfo(node_id='07963340-09f3-408f-a429-c19c025c0868', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'to_slice', 'type': 'function_definition', 'signature': 'def to_slice(self) -> slice:'}], 'start_byte': 3530, 'end_byte': 3651}, hash='34af0e0f71e6a62824a7a65c4807f514e3029ae3e94697a68e417064dfdbd998'), RelatedNodeInfo(node_id='735f887c-aa38-42de-9077-a7d571a9b809', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__str__', 'type': 'function_definition', 'signature': 'def __str__(self) -> str:'}], 'start_byte': 3653, 'end_byte': 4099}, hash='7e98c213e75cacb1a5cd246e39a46647f69ee63a378142630a7be7ff89621a08'), RelatedNodeInfo(node_id='ec7625dd-1305-4501-ba94-be8f54f2410c', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__repr__', 'type': 'function_definition', 'signature': 'def __repr__(self) -> str:'}], 'start_byte': 4101, 'end_byte': 4233}, hash='f22f1a6fc15f4e786fd891346a03e7bce9c9d5625614f569d7a4f064b8e9ab4f'), RelatedNodeInfo(node_id='98db76a5-822a-45b2-a802-5f2ce89182f1', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'indices', 'type': 'function_definition', 'signature': 'def indices(self, n: int) -> Tuple[int, int, int]:'}], 'start_byte': 4235, 'end_byte': 4643}, hash='25fa0a776e6fdbdda96c111050cd8457773984f179ba1fe1e729caae7317dd84'), RelatedNodeInfo(node_id='9b8d9306-af87-4baf-982a-a177a45d6d09', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__eq__', 'type': 'function_definition', 'signature': 'def __eq__(self, ot ...
#  TextNode(id_='7603a12a-ed6a-4623-a936-26f52007ed71', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='225ffd10d79e3e6c733ce02ba68d34f42775502a260be1ec364b2fc5a4450a03'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fc946240-6777-495f-bb2d-813994b3edbd', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='01580aece1708d09fa29e6025330b93d9603fb7a5667224c038ec14ad273f461'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='df26fae9-7ac4-4034-acec-371b72e396eb', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='47b2db5af4769c6aee9e5752cbbff2cad33140d73e6d25d699fffc8a365fb754'), <NodeRelationship.CHILD: '5'>: [RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084}, hash='2ef2bf2eba9b983e0af7d61be24ec96613f9e939f24570afb2e2f740fa85358b'), RelatedNodeInfo(node_id='0f8e7127-6943-4098-a7f3-c5a9a5410751', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'valid', 'type': 'function_definition', 'signature': 'def valid(input: Any) -> bool:'}], 'start_byte': 3104, 'end_byte': 3528}, hash='d7444197514e880201f1c889cb8f4764ac072fbe6ee5cec252db7f6ddf949502'), RelatedNodeInfo(node_id='07963340-09f3-408f-a429-c19c025c0868', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'to_slice', 'type': 'function_definition', 'signature': 'def to_slice(self) -> slice:'}], 'start_byte': 3530, 'end_byte': 3651}, hash='34af0e0f71e6a62824a7a65c4807f514e3029ae3e94697a68e417064dfdbd998'), RelatedNodeInfo(node_id='735f887c-aa38-42de-9077-a7d571a9b809', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__str__', 'type': 'function_definition', 'signature': 'def __str__(self) -> str:'}], 'start_byte': 3653, 'end_byte': 4099}, hash='7e98c213e75cacb1a5cd246e39a46647f69ee63a378142630a7be7ff89621a08'), RelatedNodeInfo(node_id='ec7625dd-1305-4501-ba94-be8f54f2410c', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__repr__', 'type': 'function_definition', 'signature': 'def __repr__(self) -> str:'}], 'start_byte': 4101, 'end_byte': 4233}, hash='f22f1a6fc15f4e786fd891346a03e7bce9c9d5625614f569d7a4f064b8e9ab4f'), RelatedNodeInfo(node_id='98db76a5-822a-45b2-a802-5f2ce89182f1', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'indices', 'type': 'function_definition', 'signature': 'def in ...
#  TextNode(id_='df26fae9-7ac4-4034-acec-371b72e396eb', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='225ffd10d79e3e6c733ce02ba68d34f42775502a260be1ec364b2fc5a4450a03'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7603a12a-ed6a-4623-a936-26f52007ed71', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='11103e126774fe6f73bcfb47f5722f4e30b037a03458311b8f9bed074459cd71'), <NodeRelationship.CHILD: '5'>: [RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084}, hash='2ef2bf2eba9b983e0af7d61be24ec96613f9e939f24570afb2e2f740fa85358b'), RelatedNodeInfo(node_id='0f8e7127-6943-4098-a7f3-c5a9a5410751', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'valid', 'type': 'function_definition', 'signature': 'def valid(input: Any) -> bool:'}], 'start_byte': 3104, 'end_byte': 3528}, hash='d7444197514e880201f1c889cb8f4764ac072fbe6ee5cec252db7f6ddf949502'), RelatedNodeInfo(node_id='07963340-09f3-408f-a429-c19c025c0868', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'to_slice', 'type': 'function_definition', 'signature': 'def to_slice(self) -> slice:'}], 'start_byte': 3530, 'end_byte': 3651}, hash='34af0e0f71e6a62824a7a65c4807f514e3029ae3e94697a68e417064dfdbd998'), RelatedNodeInfo(node_id='735f887c-aa38-42de-9077-a7d571a9b809', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__str__', 'type': 'function_definition', 'signature': 'def __str__(self) -> str:'}], 'start_byte': 3653, 'end_byte': 4099}, hash='7e98c213e75cacb1a5cd246e39a46647f69ee63a378142630a7be7ff89621a08'), RelatedNodeInfo(node_id='ec7625dd-1305-4501-ba94-be8f54f2410c', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__repr__', 'type': 'function_definition', 'signature': 'def __repr__(self) -> str:'}], 'start_byte': 4101, 'end_byte': 4233}, hash='f22f1a6fc15f4e786fd891346a03e7bce9c9d5625614f569d7a4f064b8e9ab4f'), RelatedNodeInfo(node_id='98db76a5-822a-45b2-a802-5f2ce89182f1', node_type=<ObjectType.TEXT: '1'>, metadata={'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'indices', 'type': 'function_definition', 'signature': 'def indices(self, n: int) -> Tuple[int, int, int]:'}], 'start_byte': 4235, 'end_byte': 4643}, hash='25fa0a776e6fdbdda96c111050cd8457773984f179ba1fe1e729caae7317dd84'), RelatedNodeInfo(node_id='9b8d9306-af87-4baf-982a-a177 ...
#  TextNode(id_='6efb3591-91a8-4141-8059-ca80119a87c9', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='b180fe76abf66715337fa5c0eb9a5391d75755a6dc4084c80a0cb3cc33860435'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='7f17c356-7c17-412a-bcfe-1eff27f4fdc0', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='801bf27c5ccedae98eda23e5313a7a613ab00cbeb758269c02fe21ab97ea763b'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def __init__(self, arg: Union[slice, "PageRange", str]) -> None:\n# Code replaced for brevity. See node_id 7f17c356-7c17-412a-bcfe-1eff27f4fdc0', start_char_idx=4, end_char_idx=68, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='7f17c356-7c17-412a-bcfe-1eff27f4fdc0', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='b180fe76abf66715337fa5c0eb9a5391d75755a6dc4084c80a0cb3cc33860435'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9d898e30-cd4a-440a-9581-8cf5ac097c9e', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='1410ec98904ae35e6569189a009bc03b3fefc1fd61b009c224ab927ad5e0f5a2'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='fb6e673e-2115-4f61-bc5f-9b09934458cf', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='801bf27c5ccedae98eda23e5313a7a613ab00cbeb758269c02fe21ab97ea763b'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='# Code replaced for brevity. See node_id 6efb3591-91a8-4141-8059-ca80119a87c9\n"""\n# Code replaced for brevity. See node_id fb6e673e-2115-4f61-bc5f-9b09934458cf', start_char_idx=77, end_char_idx=80, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='fb6e673e-2115-4f61-bc5f-9b09934458cf', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='b180fe76abf66715337fa5c0eb9a5391d75755a6dc4084c80a0cb3cc33860435'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7f17c356-7c17-412a-bcfe-1eff27f4fdc0', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='2ed49b72c2d51f06aeceba78b76261dff2e2342aeed863c0edd5c5f15dfeafff'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='1f0174ab-fc4a-4c66-bdca-8bfcca16793e', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c22dcfc077b04a106d83a9f7452adb7e4603b0141aa39d44e656cd1d12a7f64e'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='# Code replaced for brevity. See node_id 7f17c356-7c17-412a-bcfe-1eff27f4fdc0\n"""\n# Code replaced for brevity. See node_id 1f0174ab-fc4a-4c66-bdca-8bfcca16793e', start_char_idx=77, end_char_idx=80, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='1f0174ab-fc4a-4c66-bdca-8bfcca16793e', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6efb3591-91a8-4141-8059-ca80119a87c9', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='b180fe76abf66715337fa5c0eb9a5391d75755a6dc4084c80a0cb3cc33860435'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='fb6e673e-2115-4f61-bc5f-9b09934458cf', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__init__', 'type': 'function_definition', 'signature': 'def __init__(self, arg: Union[slice, "PageRange", str]) -> None:'}], 'start_byte': 1138, 'end_byte': 3084, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='2ed49b72c2d51f06aeceba78b76261dff2e2342aeed863c0edd5c5f15dfeafff'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='# Code replaced for brevity. See node_id fb6e673e-2115-4f61-bc5f-9b09934458cf\nif isinstance(arg, slice):\n            self._slice = arg\n            return\n\n        if isinstance(arg, PageRange):\n            self._slice = arg.to_slice()\n            return\n\n        m = isinstance(arg, str) and re.match(PAGE_RANGE_RE, arg)\n        if not m:\n            raise ParseError(arg)\n        elif m.group(2):\n            # Special case: just an int means a range of one page.\n            start = int(m.group(2))\n            stop = start + 1 if start != -1 else None\n            self._slice = slice(start, stop)\n        else:\n            self._slice = slice(*[int(g) if g else None for g in m.group(4, 6, 8)])', start_char_idx=1327, end_char_idx=1946, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='0f8e7127-6943-4098-a7f3-c5a9a5410751', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'valid', 'type': 'function_definition', 'signature': 'def valid(input: Any) -> bool:'}], 'start_byte': 3104, 'end_byte': 3528, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0f8e7127-6943-4098-a7f3-c5a9a5410751', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'valid', 'type': 'function_definition', 'signature': 'def valid(input: Any) -> bool:'}], 'start_byte': 3104, 'end_byte': 3528, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='5c24254a90913611e92be758b2cbbb0ab723635918070792067b0cc0a545662b'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def valid(input: Any) -> bool:\n        """\n        True if input is a valid initializer for a PageRange.\n\n        Args:\n            input: A possible PageRange string or a PageRange object.\n\n        Returns:\n            True, if the ``input`` is a valid PageRange.\n        """\n        return isinstance(input, (slice, PageRange)) or (\n            isinstance(input, str) and bool(re.match(PAGE_RANGE_RE, input))\n        )', start_char_idx=4, end_char_idx=424, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='07963340-09f3-408f-a429-c19c025c0868', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'to_slice', 'type': 'function_definition', 'signature': 'def to_slice(self) -> slice:'}], 'start_byte': 3530, 'end_byte': 3651, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='07963340-09f3-408f-a429-c19c025c0868', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'to_slice', 'type': 'function_definition', 'signature': 'def to_slice(self) -> slice:'}], 'start_byte': 3530, 'end_byte': 3651, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='d8e385f2676af0815305f9f822546e994cde32d64851d318671d299bc48960fd'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def to_slice(self) -> slice:\n        """Return the slice equivalent of this page range."""\n        return self._slice', start_char_idx=4, end_char_idx=121, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='735f887c-aa38-42de-9077-a7d571a9b809', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__str__', 'type': 'function_definition', 'signature': 'def __str__(self) -> str:'}], 'start_byte': 3653, 'end_byte': 4099, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='735f887c-aa38-42de-9077-a7d571a9b809', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__str__', 'type': 'function_definition', 'signature': 'def __str__(self) -> str:'}], 'start_byte': 3653, 'end_byte': 4099, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='7c283aaa47212448c5bb3db65c640b5d8f0b559ea4aa4f60154a93cfbc467a69'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def __str__(self) -> str:\n        """A string like "1:2:3"."""\n        s = self._slice\n        indices: Union[Tuple[int, int], Tuple[int, int, int]]\n        if s.step is None:\n            if s.start is not None and s.stop == s.start + 1:\n                return str(s.start)\n\n            indices = s.start, s.stop\n        else:\n            indices = s.start, s.stop, s.step\n        return ":".join("" if i is None else str(i) for i in indices)', start_char_idx=4, end_char_idx=446, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='ec7625dd-1305-4501-ba94-be8f54f2410c', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__repr__', 'type': 'function_definition', 'signature': 'def __repr__(self) -> str:'}], 'start_byte': 4101, 'end_byte': 4233, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ec7625dd-1305-4501-ba94-be8f54f2410c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__repr__', 'type': 'function_definition', 'signature': 'def __repr__(self) -> str:'}], 'start_byte': 4101, 'end_byte': 4233, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='467b1afb61f6a45f9a70f791ac6cb0693e3eac70b122d55359626e3b1c303c76'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def __repr__(self) -> str:\n        """A string like "PageRange(\'1:2:3\')"."""\n        return "PageRange(" + repr(str(self)) + ")"', start_char_idx=4, end_char_idx=132, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='98db76a5-822a-45b2-a802-5f2ce89182f1', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'indices', 'type': 'function_definition', 'signature': 'def indices(self, n: int) -> Tuple[int, int, int]:'}], 'start_byte': 4235, 'end_byte': 4643, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='98db76a5-822a-45b2-a802-5f2ce89182f1', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': 'indices', 'type': 'function_definition', 'signature': 'def indices(self, n: int) -> Tuple[int, int, int]:'}], 'start_byte': 4235, 'end_byte': 4643, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='7c8427c4036a44000e3dc1933c0db05cf834e2b12e68f99c4cc517d07a42487e'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def indices(self, n: int) -> Tuple[int, int, int]:\n        """\n        Assuming a sequence of length n, calculate the start and stop indices,\n        and the stride length of the PageRange.\n\n        See help(slice.indices).\n\n        Args:\n            n:  the length of the list of pages to choose from.\n\n        Returns:\n            Arguments for range()\n        """\n        return self._slice.indices(n)', start_char_idx=4, end_char_idx=408, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='9b8d9306-af87-4baf-982a-a177a45d6d09', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__eq__', 'type': 'function_definition', 'signature': 'def __eq__(self, other: object) -> bool:'}], 'start_byte': 4645, 'end_byte': 4802, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9b8d9306-af87-4baf-982a-a177a45d6d09', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__eq__', 'type': 'function_definition', 'signature': 'def __eq__(self, other: object) -> bool:'}], 'start_byte': 4645, 'end_byte': 4802, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='fe7819d0a0e3f5401ee2a1eb78d47537b26355ec1e71abe69351947522401f5e'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def __eq__(self, other: object) -> bool:\n        if not isinstance(other, PageRange):\n            return False\n        return self._slice == other._slice', start_char_idx=4, end_char_idx=157, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='5eb6c661-fb12-4d96-961c-4e068e83a7b6', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__add__', 'type': 'function_definition', 'signature': 'def __add__(self, other: "PageRange") -> "PageRange":'}], 'start_byte': 4804, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5eb6c661-fb12-4d96-961c-4e068e83a7b6', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}, {'name': '__add__', 'type': 'function_definition', 'signature': 'def __add__(self, other: "PageRange") -> "PageRange":'}], 'start_byte': 4804, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='5174f3b0c2569d725e0e32a35f13879f8abe4fb6b4319d1c744b72eee13c4ec6'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='a4d522d2-982f-4cc6-ba4b-8870ac8ed52c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'PageRange', 'type': 'class_definition', 'signature': 'class PageRange:'}], 'start_byte': 523, 'end_byte': 5484, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='3927b2b47525399ba31ccd96677e177efa9e6a40403d89978094294e83b77d7f')}, text='def __add__(self, other: "PageRange") -> "PageRange":\n        if not isinstance(other, PageRange):\n            raise TypeError(f"Can\'t add PageRange and {type(other)}")\n        if self._slice.step is not None or other._slice.step is not None:\n            raise ValueError("Can\'t add PageRange with stride")\n        a = self._slice.start, self._slice.stop\n        b = other._slice.start, other._slice.stop\n\n        if a[0] > b[0]:\n            a, b = b, a\n\n        # Now a[0] is the smallest\n        if b[0] > a[1]:\n            # There is a gap between a and b.\n            raise ValueError("Can\'t add PageRanges with gap")\n        return PageRange(slice(a[0], max(a[1], b[1])))', start_char_idx=4, end_char_idx=680, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='446ebec5-d6fa-4cd6-996d-58da053ef58c', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='446ebec5-d6fa-4cd6-996d-58da053ef58c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='0b2312a6eebb7d95667b883893c4aa5f0c8f5fd0ffae0bf47f2e1350658e76de'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='dac9ca44-f857-459e-8ea6-313ae2f83c78', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='1cd5351a9ac2c4b1b575d7d39113b6d1ebf4df2038ffcfa281d930e263650199'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='152c4556-8642-48bd-bc08-32a95ce64d97', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [], 'start_byte': 0, 'end_byte': 6880, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='9f1d56e3681f737ea08a2650b69b0d91e44816da6bf61a0694ad04ee2d49ae80')}, text='def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:\n# Code replaced for brevity. See node_id dac9ca44-f857-459e-8ea6-313ae2f83c78', start_char_idx=0, end_char_idx=109, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='dac9ca44-f857-459e-8ea6-313ae2f83c78', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='446ebec5-d6fa-4cd6-996d-58da053ef58c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='0b2312a6eebb7d95667b883893c4aa5f0c8f5fd0ffae0bf47f2e1350658e76de'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='76f3617d-abb8-479e-9ccc-e40ef2a2d5d5', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='bc2ce9f176498959289f5bffdd3451c819b53275cc7194c59160c4e34ccabf9a'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='f8a5c298-6128-45d8-a2c7-b3f1b376a8b7', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='a7ae98a8134ce00e6c7025a0e24ace725adbf1a8b2493ad1e1553c3375dc9442'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='152c4556-8642-48bd-bc08-32a95ce64d97', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [], 'start_byte': 0, 'end_byte': 6880, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='9f1d56e3681f737ea08a2650b69b0d91e44816da6bf61a0694ad04ee2d49ae80')}, text='# Code replaced for brevity. See node_id 446ebec5-d6fa-4cd6-996d-58da053ef58c\n"""\n    Given a list of filenames and page ranges, return a list of (filename, page_range) pairs.\n\n    Args:\n        args: A list where the first element is a filename. The other elements are\n            filenames, page-range expressions, slice objects, or PageRange objects.\n            A filename not followed by a page range indicates all pages of the file.\n\n    Returns:\n        A list of (filename, page_range) pairs.\n    """\n    pairs: List[Tuple[str, PageRange]] = []\n    pdf_filename = None\n    did_page_range = False\n# Code replaced for brevity. See node_id f8a5c298-6128-45d8-a2c7-b3f1b376a8b7', start_char_idx=114, end_char_idx=639, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='f8a5c298-6128-45d8-a2c7-b3f1b376a8b7', embedding=None, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='446ebec5-d6fa-4cd6-996d-58da053ef58c', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='0b2312a6eebb7d95667b883893c4aa5f0c8f5fd0ffae0bf47f2e1350658e76de'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='dac9ca44-f857-459e-8ea6-313ae2f83c78', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [{'name': 'parse_filename_page_ranges', 'type': 'function_definition', 'signature': 'def parse_filename_page_ranges(\n    args: List[Union[str, PageRange, None]]\n) -> List[Tuple[str, PageRange]]:'}], 'start_byte': 5548, 'end_byte': 6789, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='330769b933928ad29ac2c21473cc6392692ea8917b4be944e4346e374cece30e'), <NodeRelationship.CHILD: '5'>: [], <NodeRelationship.PARENT: '4'>: RelatedNodeInfo(node_id='152c4556-8642-48bd-bc08-32a95ce64d97', node_type=<ObjectType.TEXT: '1'>, metadata={'language': 'python', 'inclusive_scopes': [], 'start_byte': 0, 'end_byte': 6880, 'filepath': 'C:\\Dev\\POC\\.venv\\Lib\\site-packages\\pypdf\\pagerange.py'}, hash='9f1d56e3681f737ea08a2650b69b0d91e44816da6bf61a0694ad04ee2d49ae80')}, text='# Code replaced for brevity. See node_id dac9ca44-f857-459e-8ea6-313ae2f83c78\nfor arg in args + [None]:\n        if PageRange.valid(arg):\n            if not pdf_filename:\n                raise ValueError(\n                    "The first argument must be a filename, not a page range."\n                )\n\n            pairs.append((pdf_filename, PageRange(arg)))\n            did_page_range = True\n        else:\n            # New filename or end of list--do all of the previous file?\n            if pdf_filename and not did_page_range:\n                pairs.append((pdf_filename, PAGE_RANGE_ALL))\n\n            pdf_filename = arg\n            did_page_range = False\n    return pairs', start_char_idx=644, end_char_idx=1241, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
print(CodeHierarchyNodeParser.get_code_hierarchy_from_nodes(split_nodes))
# Out:
# (defaultdict(<class 'dict'>, {'C:\\Dev\\POC\\': defaultdict(<class 'dict'>, {'PageRange': defaultdict(<class 'dict'>, {'__init__': defaultdict(<class 'dict'>, {}), 'valid': defaultdict(<class 'dict'>, {}), 'to_slice': defaultdict(<class 'dict'>, {}), '__str__': defaultdict(<class 'dict'>, {}), '__repr__': defaultdict(<class 'dict'>, {}), 'indices': defaultdict(<class 'dict'>, {}), '__eq__': defaultdict(<class 'dict'>, {}), '__add__': defaultdict(<class 'dict'>, {})}), 'parse_filename_page_ranges': defaultdict(<class 'dict'>, {})})}), '- C:\\Dev\\POC\\\n  - PageRange\n    - __init__\n    - valid\n    - to_slice\n    - __str__\n    - __repr__\n    - indices\n    - __eq__\n    - __add__\n  - parse_filename_page_ranges\n')

# %%
split_nodes_by_id = {n.node_id: n for n in split_nodes}
uuid_from_text = split_nodes[9].text.splitlines()[-1].split(" ")[-1]
print("Going to print the node with UUID:", uuid_from_text)
#print_python(split_nodes_by_id[uuid_from_text].text)
# Out:
# Going to print the node with UUID: self._slice

# %%
from IPython.display import Markdown, display


def print_python(python_text):
    """This function prints python text in ipynb nicely formatted."""
    display(Markdown("```python\n" + python_text + "```"))

# %%
from llama_index.packs.code_hierarchy import CodeHierarchyKeywordQueryEngine

query_engine = CodeHierarchyKeywordQueryEngine(
    nodes=split_nodes,
)

# %%
print_python(query_engine.query(split_nodes[0].node_id).response)
# Out:
# ```python
# """
# Representation and utils for ranges of PDF file pages.
#
# Copyright (c) 2014, Steve Witham <switham_github@mac-guyver.com>.
# All rights reserved. This software is available under a BSD license;
# see https://github.com/py-pdf/pypdf/blob/main/LICENSE
# """
#
# import re
# from typing import Any, List, Tuple, Union
#
# from .errors import ParseError
#
# _INT_RE = r"(0|-?[1-9]\d*)"  # A decimal int, don't allow "-0".
# PAGE_RANGE_RE = f"^({_INT_RE}|({_INT_RE}?(:{_INT_RE}?(:{_INT_RE}?)?)))$"
# # groups:         12     34     5 6     7 8
#
#
# class PageRange:
#     # Code replaced for brevity. See node_id a4d522d2-982f-4cc6-ba4b-8870ac8ed52c
#
#
# PAGE_RANGE_ALL = PageRange(":")  # The range of all pages.
#
#
# def parse_filename_page_ranges(
#     args: List[Union[str, PageRange, None]]
# ) -> List[Tuple[str, PageRange]]:
#     # Code replaced for brevity. See node_id 446ebec5-d6fa-4cd6-996d-58da053ef58c
#
#
# PageRangeSpec = Union[str, PageRange, Tuple[int, int], Tuple[int, int, int], List[int]]```

# %%
from llama_index.core.tools import QueryEngineTool

tool = QueryEngineTool.from_defaults(
    query_engine=query_engine,
    name="code_lookup",
    description="Useful for looking up information about the code hierarchy codebase.",
)

# %%
display(Markdown("Description: " + query_engine.get_tool_instructions()))
# Out:
# Description: Search the tool by any element in this list to get more information about that element.
# If you see 'Code replaced for brevity' then a uuid, you may also search the tool with that uuid to see the full code.
# You may need to use the tool multiple times to fully answer the user message.
# The list is:
# - C:\Dev\POC\
#   - PageRange
#     - __init__
#     - valid
#     - to_slice
#     - __str__
#     - __repr__
#     - indices
#     - __eq__
#     - __add__
#   - parse_filename_page_ranges
